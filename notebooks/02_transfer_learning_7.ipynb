# %%
from pathlib import Path
import os

IMAGES_PATH = Path("../resources/cloud-images/CCSN_v2")

def index_labeled_images(images_path=IMAGES_PATH):
    images_path = Path(images_path)
    labeled_images = {}
    if not images_path.exists():
        return labeled_images

    for cloud_dir in sorted(p for p in images_path.iterdir() if p.is_dir()):
        for img_path in sorted(p for p in cloud_dir.iterdir() if p.is_file()):
            labeled_images[img_path.name] = {
                "label": cloud_dir.name,
                "path": str(img_path)
            }

    return labeled_images

# %%
labeled_images = index_labeled_images()

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

def extract_labels(labeled_images):
    labels = []
    paths = []
    for (i, image_name) in enumerate(labeled_images):
        path = labeled_images[image_name]['path']
        paths.append(path)
        label = labeled_images[image_name]['label']
        labels.append(label)

    return paths, np.array(labels)

# %%
paths, labels = extract_labels(labeled_images)

# %%
print(labels)
# Out:
# ['Ac' 'Ac' 'Ac' ... 'St' 'St' 'St']

# %%
print(paths)
# Out:
# ['../resources/cloud-images/CCSN_v2/Ac/Ac-N001.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N002.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N003.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N004.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N005.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N006.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N007.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N008.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N009.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N010.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N011.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N012.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N013.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N014.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N015.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N016.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N017.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N018.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N019.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N020.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N021.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N022.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N023.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N024.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N025.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N026.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N027.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N028.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N029.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N030.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N031.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N032.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N033.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N034.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N035.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N036.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N037.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N038.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N039.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N040.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N041.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N042.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N043.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N044.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N045.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N046.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N047.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N048.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N049.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N050.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N051.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N052.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N053.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N054.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N055.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N056.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N057.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N058.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N059.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N060.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N061.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N062.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N063.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N064.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N065.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N066.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N067.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N068.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N069.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N070.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N071.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N072.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N073.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N074.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N075.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N076.jpg', '../resources/cloud-images/CCSN_v2/Ac/Ac-N077.j ...

# %%
import torch

if torch.cuda.is_available():
    device = "cuda"
elif torch.backends.mps.is_available():
    device = "mps"
else:
    device = "cpu"

device
# Out:
# 'mps'

# %%
from torch.utils.data import DataLoader
import torchvision
import torch.nn as nn
from functools import partial

# %%
torchvision.models.list_models()
# Out:
# ['alexnet',
#  'convnext_base',
#  'convnext_large',
#  'convnext_small',
#  'convnext_tiny',
#  'deeplabv3_mobilenet_v3_large',
#  'deeplabv3_resnet101',
#  'deeplabv3_resnet50',
#  'densenet121',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'efficientnet_b0',
#  'efficientnet_b1',
#  'efficientnet_b2',
#  'efficientnet_b3',
#  'efficientnet_b4',
#  'efficientnet_b5',
#  'efficientnet_b6',
#  'efficientnet_b7',
#  'efficientnet_v2_l',
#  'efficientnet_v2_m',
#  'efficientnet_v2_s',
#  'fasterrcnn_mobilenet_v3_large_320_fpn',
#  'fasterrcnn_mobilenet_v3_large_fpn',
#  'fasterrcnn_resnet50_fpn',
#  'fasterrcnn_resnet50_fpn_v2',
#  'fcn_resnet101',
#  'fcn_resnet50',
#  'fcos_resnet50_fpn',
#  'googlenet',
#  'inception_v3',
#  'keypointrcnn_resnet50_fpn',
#  'lraspp_mobilenet_v3_large',
#  'maskrcnn_resnet50_fpn',
#  'maskrcnn_resnet50_fpn_v2',
#  'maxvit_t',
#  'mc3_18',
#  'mnasnet0_5',
#  'mnasnet0_75',
#  'mnasnet1_0',
#  'mnasnet1_3',
#  'mobilenet_v2',
#  'mobilenet_v3_large',
#  'mobilenet_v3_small',
#  'mvit_v1_b',
#  'mvit_v2_s',
#  'quantized_googlenet',
#  'quantized_inception_v3',
#  'quantized_mobilenet_v2',
#  'quantized_mobilenet_v3_large',
#  'quantized_resnet18',
#  'quantized_resnet50',
#  'quantized_resnext101_32x8d',
#  'quantized_resnext101_64x4d',
#  'quantized_shufflenet_v2_x0_5',
#  'quantized_shufflenet_v2_x1_0',
#  'quantized_shufflenet_v2_x1_5',
#  'quantized_shufflenet_v2_x2_0',
#  'r2plus1d_18',
#  'r3d_18',
#  'raft_large',
#  'raft_small',
#  'regnet_x_16gf',
#  'regnet_x_1_6gf',
#  'regnet_x_32gf',
#  'regnet_x_3_2gf',
#  'regnet_x_400mf',
#  'regnet_x_800mf',
#  'regnet_x_8gf',
#  'regnet_y_128gf',
#  'regnet_y_16gf',
#  'regnet_y_1_6gf',
#  'regnet_y_32gf',
#  'regnet_y_3_2gf',
#  'regnet_y_400mf',
#  'regnet_y_800mf',
#  'regnet_y_8gf',
#  'resnet101',
#  'resnet152',
#  'resnet18',
#  'resnet34',
#  'resnet50',
#  'resnext101_32x8d',
#  'resnext101_64x4d',
#  'resnext50_32x4d',
#  'retinanet_resnet50_fpn',
#  'retinanet_resnet50_fpn_v2',
#  's3d',
#  'shufflenet_v2_x0_5',
#  'shufflenet_v2_x1_0',
#  'shufflenet_v2_x1_5',
#  'shufflenet_v2_x2_0',
#  'squeezenet1_0',
#  'squeezenet1_1',
#  'ssd300_vgg16',
#  'ssdlite320_mobilenet_v3_large',
#  'swin3d_b',
#  'swin3d_s',
#  'swin3d_t',
#  'swin_b',
#  'swin_s',
#  'swin_t',
#  'swin_v2_b',
#  'swin_v2_s',
#  'swin_v2_t',
#  'vgg11',
#  'vgg11_bn',
#  'vgg13',
#  'vgg13_bn',
#  'vgg16',
#  'vgg16_bn',
#  'vgg19',
#  'vgg19_bn',
#  'vit_b_16',
#  'vit_b_32',
#  'vit_h_14',
#  'vit_l_16',
#  'vit_l_32',
#  'wide_resnet101_2',
#  'wide_resnet50_2']

# %%
list(torchvision.models.get_model_weights("vit_b_16"))
# Out:
# [ViT_B_16_Weights.IMAGENET1K_V1,
#  ViT_B_16_Weights.IMAGENET1K_SWAG_E2E_V1,
#  ViT_B_16_Weights.IMAGENET1K_SWAG_LINEAR_V1]

# %%
weights = torchvision.models.ViT_B_16_Weights.IMAGENET1K_SWAG_E2E_V1
model = torchvision.models.vit_b_16(weights=weights).to(device)

# %%
import torchvision.transforms.v2 as T

transforms = weights.transforms()
# transforms = T.Compose([
#     T.RandomHorizontalFlip(p=0.5),
#     T.RandomRotation(degrees=30),
#     T.RandomResizedCrop(size=(384, 384), scale=(0.8, 1.0)),
#     T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
#     T.ToImage(),
#     T.ToDtype(torch.float32, scale=True),
#     T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
# ])

# %%
print(transforms)
# Out:
# ImageClassification(
#     crop_size=[384]
#     resize_size=[384]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BICUBIC
# )

# %%
from sklearn.preprocessing import LabelEncoder

def encode_labels(labels):
    ordinal_encoder = LabelEncoder()
    encoded_labels = ordinal_encoder.fit_transform(labels)
    class_names = ordinal_encoder.classes_
    return encoded_labels, class_names

# %%
encoded_labels, class_names = encode_labels(labels)

# %%
print(class_names)
# Out:
# ['Ac' 'As' 'Cb' 'Cc' 'Ci' 'Cs' 'Ct' 'Cu' 'Ns' 'Sc' 'St']

# %%
print(encoded_labels)
# Out:
# [ 0  0  0 ... 10 10 10]

# %%
from torch.utils.data import Dataset
from sklearn.model_selection import StratifiedShuffleSplit
from PIL import Image
import numpy as np

class MyImages(Dataset):
    def __init__(self, paths, encoded_labels, split="train", test_size=0.2, val_size=0.1, random_state=42, transform=None,
                 split_indices=None):

        if split not in {None, "train", "val", "test"}:
            raise ValueError(f"split must be one of {{'None','train','val','test'}}, got {split!r}")

        self.transform = transform

        paths = np.array(list(paths))
        encoded_labels = np.array(list(encoded_labels))

        n = len(paths)
        if n != len(encoded_labels):
            raise ValueError(f"paths and encoded_labels must have same length, got {n} and {len(labels)}")

        if split_indices is None:
            sss1 = StratifiedShuffleSplit(n_splits=1, test_size=test_size, random_state=random_state)
            trainval_idx, test_idx = next(sss1.split(paths, encoded_labels))

            trainval_fraction = 1.0 - test_size
            val_within_trainval = val_size / trainval_fraction

            sss2 = StratifiedShuffleSplit(n_splits=1, test_size=val_within_trainval, random_state=random_state)

            trainval_paths = paths[trainval_idx]
            trainval_labels = encoded_labels[trainval_idx]

            train_rel_idx, val_rel_idx = next(sss2.split(trainval_paths, trainval_labels))
            train_idx = trainval_idx[train_rel_idx]
            val_idx = trainval_idx[val_rel_idx]

            split_indices = {"train": train_idx, "val": val_idx, "test": test_idx}

        idx = split_indices[split]

        self.paths = paths[idx].tolist()
        self.encoded_labels = encoded_labels[idx].tolist()

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, idx):
        img = Image.open(self.paths[idx]).convert("RGB")
        if self.transform:
            img = self.transform(img)
        return img, self.encoded_labels[idx]

# %%
from functools import partial

DefaultCloudImages = partial(
    MyImages,
    paths=paths,
    encoded_labels=encoded_labels,
    transform=transforms,
    test_size=0.2,
    val_size=0.1,
    random_state=42
)

# %%
train_set = DefaultCloudImages(split="train")
valid_set = DefaultCloudImages(split="val")
test_set = DefaultCloudImages(split="test")

# %%
train_set[0]
# Out:
# (Image([[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#          [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#          [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#          ...,
#          [-2.1179, -2.1179, -2.1179,  ..., -1.0390, -1.0390, -1.0562],
#          [-2.1179, -2.1179, -2.1179,  ..., -1.0390, -1.0390, -1.0390],
#          [-2.1179, -2.1179, -2.1179,  ..., -1.0390, -1.0390, -1.0733]],
#
#         [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#          [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#          [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#          ...,
#          [-2.0357, -2.0357, -2.0357,  ..., -0.9678, -0.9678, -0.9853],
#          [-2.0357, -2.0357, -2.0357,  ..., -0.9678, -0.9678, -0.9678],
#          [-2.0357, -2.0357, -2.0357,  ..., -0.9678, -0.9678, -0.9678]],
#
#         [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#          [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#          [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#          ...,
#          [-1.8044, -1.8044, -1.8044,  ..., -0.6367, -0.6367, -0.5844],
#          [-1.8044, -1.8044, -1.8044,  ..., -0.6367, -0.6367, -0.6367],
#          [-1.8044, -1.8044, -1.8044,  ..., -0.6541, -0.6541, -0.6367]]], ),
#  9)

# %%
len(train_set)
len(valid_set)
len(test_set)
# Out:
# 509

# %%
display_transform = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.CenterCrop(500),
])

# create a dataset instance for the train split (use MyImages to request a split)
clouds_to_display = DefaultCloudImages(split="train", transform=display_transform)

# %%
def plot_image(image):
    plt.imshow(image.permute(1, 2, 0))
    plt.axis("off")

# %%
sample_clouds = sorted({y: img for img, y in clouds_to_display}.items())[:11]

plt.figure(figsize=(10, 6))
for class_id, image in sample_clouds:
    if class_id == 11: break
    plt.subplot(3, 4, class_id + 1)
    plot_image(image)
    plt.title(f"{class_id}: {class_names[class_id]}", fontsize=11)

plt.show()

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=32)
test_loader = DataLoader(test_set, batch_size=32)

# %%
[name for name, child in model.named_children()]
# Out:
# ['conv_proj', 'encoder', 'heads']

# %%
model.heads
# Out:
# Sequential(
#   (head): Linear(in_features=768, out_features=1000, bias=True)
# )

# %%
model.encoder
# Out:
# Encoder(
#   (dropout): Dropout(p=0.0, inplace=False)
#   (layers): Sequential(
#     (encoder_layer_0): EncoderBlock(
#       (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (self_attention): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#       (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): MLPBlock(
#         (0): Linear(in_features=768, out_features=3072, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.0, inplace=False)
#         (3): Linear(in_features=3072, out_features=768, bias=True)
#         (4): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (encoder_layer_1): EncoderBlock(
#       (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (self_attention): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#       (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): MLPBlock(
#         (0): Linear(in_features=768, out_features=3072, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.0, inplace=False)
#         (3): Linear(in_features=3072, out_features=768, bias=True)
#         (4): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (encoder_layer_2): EncoderBlock(
#       (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (self_attention): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#       (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): MLPBlock(
#         (0): Linear(in_features=768, out_features=3072, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.0, inplace=False)
#         (3): Linear(in_features=3072, out_features=768, bias=True)
#         (4): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (encoder_layer_3): EncoderBlock(
#       (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (self_attention): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#       (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): MLPBlock(
#         (0): Linear(in_features=768, out_features=3072, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.0, inplace=False)
#         (3): Linear(in_features=3072, out_features=768, bias=True)
#         (4): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (encoder_layer_4): EncoderBlock(
#       (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (self_attention): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#       (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): MLPBlock(
#         (0): Linear(in_features=768, out_features=3072, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.0, inplace=False)
#         (3): Linear(in_features=3072, out_features=768, bias=True)
#         (4): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (encoder_layer_5): EncoderBlock(
#       (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (self_attention): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#       (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): MLPBlock(
#         (0): Linear(in_features=768, out_features=3072, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.0, inplace=False)
#         (3): Linear(in_features=3072, out_features=768, bias=True)
#         (4): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (encoder_layer_6): EncoderBlock(
#       (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (self_attention): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#       (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): MLPBlock(
#         (0): Linear(in_features=768, out_features=3072, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.0, inplace=False)
#         (3): Linear(in_features=3072, out_features=768, bias=True)
#         (4): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (encoder_layer_7): EncoderBlock(
#       (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (self_attention): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#       (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): MLPBlock(
#         (0): Linear(in_features=768, out_features=3072, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.0, inplace=False)
#         (3): Linear(in_features=3072, out_features=768, bias=True)
#         (4): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (encoder_layer_8): EncoderBlock(
#       (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (self_attention): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#       (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): MLPBlock(
#         (0): Linear(in_features=768, out_features=3072, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.0, inplace=False)
#         (3): Linear(in_features=3072, out_features=768, bias=True)
#         (4): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (encoder_layer_9): EncoderBlock(
#       (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (self_attention): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#       (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): MLPBlock(
#         (0): Linear(in_features=768, out_features=3072, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.0, inplace=False)
#         (3): Linear(in_features=3072, out_features=768, bias=True)
#         (4): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (encoder_layer_10): EncoderBlock(
#       (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (self_attention): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#       (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): MLPBlock(
#         (0): Linear(in_features=768, out_features=3072, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.0, inplace=False)
#         (3): Linear(in_features=3072, out_features=768, bias=True)
#         (4): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (encoder_layer_11): EncoderBlock(
#       (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (self_attention): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#       (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): MLPBlock(
#         (0): Linear(in_features=768, out_features=3072, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.0, inplace=False)
#         (3): Linear(in_features=3072, out_features=768, bias=True)
#         (4): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (ln): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
# )

# %%
model.conv_proj
# Out:
# Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))

# %%
n_classes = 11
model.heads[0] = nn.Linear(768, n_classes).to(device)

# %%
for param in model.parameters():
    param.requires_grad = False

for param in model.heads.parameters():
    param.requires_grad = True

# %%
import torchmetrics

def evaluate_tm(model, data_loader, metric):
    model.eval()
    metric.reset()
    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_pred = model(X_batch)
            metric.update(y_pred, y_batch)
    return metric.compute()

def train(model, optimizer, loss_fn, metric, train_loader, valid_loader,
          n_epochs):
    history = {"train_losses": [], "train_metrics": [], "valid_metrics": []}
    for epoch in range(n_epochs):
        total_loss = 0.0
        metric.reset()
        model.train()
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_pred = model(X_batch)
            loss = loss_fn(y_pred, y_batch)
            total_loss += loss.item()
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            metric.update(y_pred, y_batch)
        history["train_losses"].append(total_loss / len(train_loader))
        history["train_metrics"].append(metric.compute().item())
        history["valid_metrics"].append(
            evaluate_tm(model, valid_loader, metric).item())
        print(f"Epoch {epoch + 1}/{n_epochs}, "
              f"train loss: {history['train_losses'][-1]:.4f}, "
              f"train metric: {history['train_metrics'][-1]:.4f}, "
              f"valid metric: {history['valid_metrics'][-1]:.4f}")
    return history

# %%
n_epochs = 10
optimizer = torch.optim.AdamW(model.parameters())
xentropy = nn.CrossEntropyLoss()
accuracy = torchmetrics.Accuracy(task="multiclass",
                                 num_classes=11).to(device)

for i in range(30):
    print("Run #{}".format(i + 1))
    history = train(model, optimizer, xentropy, accuracy,
                    train_loader, valid_loader, n_epochs)
    print(evaluate_tm(model, test_loader, accuracy))
# Out:
# Run #1
# Epoch 1/10, train loss: 1.9819, train metric: 0.3210, valid metric: 0.4157
# Epoch 2/10, train loss: 1.5880, train metric: 0.4621, valid metric: 0.4353
# Epoch 3/10, train loss: 1.4522, train metric: 0.5098, valid metric: 0.4471
# Epoch 4/10, train loss: 1.4014, train metric: 0.5323, valid metric: 0.4667
# Epoch 5/10, train loss: 1.3508, train metric: 0.5537, valid metric: 0.4745
# Epoch 6/10, train loss: 1.3224, train metric: 0.5436, valid metric: 0.4706
# Epoch 7/10, train loss: 1.2621, train metric: 0.5548, valid metric: 0.4784
# Epoch 8/10, train loss: 1.2608, train metric: 0.5632, valid metric: 0.4431
# Epoch 9/10, train loss: 1.2233, train metric: 0.5694, valid metric: 0.4667
# Epoch 10/10, train loss: 1.2099, train metric: 0.5705, valid metric: 0.4706
# tensor(0.4597, device='mps:0')
# Run #2
# Epoch 1/10, train loss: 1.2037, train metric: 0.5868, valid metric: 0.4941
# Epoch 2/10, train loss: 1.1645, train metric: 0.5897, valid metric: 0.4588
# Epoch 3/10, train loss: 1.1243, train metric: 0.6037, valid metric: 0.4824
# Epoch 4/10, train loss: 1.1369, train metric: 0.6088, valid metric: 0.5333
# Epoch 5/10, train loss: 1.1230, train metric: 0.6093, valid metric: 0.4784
# Epoch 6/10, train loss: 1.0771, train metric: 0.6217, valid metric: 0.4824
# Epoch 7/10, train loss: 1.1033, train metric: 0.6110, valid metric: 0.4941
# Epoch 8/10, train loss: 1.0572, train metric: 0.6239, valid metric: 0.5098
# Epoch 9/10, train loss: 1.0728, train metric: 0.6386, valid metric: 0.4941
# Epoch 10/10, train loss: 1.0578, train metric: 0.6256, valid metric: 0.5137
# tensor(0.4754, device='mps:0')
# Run #3
# Epoch 1/10, train loss: 1.0428, train metric: 0.6341, valid metric: 0.4824
# Epoch 2/10, train loss: 1.0311, train metric: 0.6402, valid metric: 0.4902
# Epoch 3/10, train loss: 1.0296, train metric: 0.6391, valid metric: 0.4510
# Epoch 4/10, train loss: 1.0266, train metric: 0.6509, valid metric: 0.5020
# Epoch 5/10, train loss: 1.0329, train metric: 0.6431, valid metric: 0.4706
# Epoch 6/10, train loss: 1.0203, train metric: 0.6487, valid metric: 0.4706
# Epoch 7/10, train loss: 1.0012, train metric: 0.6588, valid metric: 0.5020
# Epoch 8/10, train loss: 0.9899, train metric: 0.6655, valid metric: 0.5176
# Epoch 7/10, train loss: 0.7203, train metric: 0.7319, valid metric: 0.4863
# Epoch 8/10, train loss: 0.7041, train metric: 0.7504, valid metric: 0.4980
# Epoch 9/10, train loss: 0.7251, train metric: 0.7437, valid metric: 0.4627
# Epoch 10/10, train loss: 0.6904, train metric: 0.7605, valid metric: 0.4745
# tensor(0.4931, device='mps:0')
# Run #25
# Epoch 1/10, train loss: 0.7205, train metric: 0.7431, valid metric: 0.4863
# Epoch 2/10, train loss: 0.7115, train metric: 0.7504, valid metric: 0.4980
# Epoch 3/10, train loss: 0.7315, train metric: 0.7240, valid metric: 0.4980
# Epoch 4/10, train loss: 0.6947, train metric: 0.7577, valid metric: 0.5020
# Epoch 5/10, train loss: 0.7000, train metric: 0.7510, valid metric: 0.5137
# Epoch 6/10, train loss: 0.6982, train metric: 0.7347, valid metric: 0.5137
# Epoch 7/10, train loss: 0.7053, train metric: 0.7409, valid metric: 0.4941
# Epoch 8/10, train loss: 0.7192, train metric: 0.7397, valid metric: 0.4824
# Epoch 9/10, train loss: 0.7060, train metric: 0.7459, valid metric: 0.4902
# Epoch 10/10, train loss: 0.6909, train metric: 0.7515, valid metric: 0.4824
# tensor(0.4813, device='mps:0')
# Run #26
# Epoch 1/10, train loss: 0.7038, train metric: 0.7510, valid metric: 0.5059
# Epoch 2/10, train loss: 0.7265, train metric: 0.7347, valid metric: 0.5059
# Epoch 3/10, train loss: 0.6855, train metric: 0.7577, valid metric: 0.4824
# Epoch 4/10, train loss: 0.7039, train metric: 0.7544, valid metric: 0.5020
# Epoch 5/10, train loss: 0.7379, train metric: 0.7364, valid metric: 0.5059
# Epoch 6/10, train loss: 0.7170, train metric: 0.7369, valid metric: 0.4980
# Epoch 7/10, train loss: 0.7206, train metric: 0.7409, valid metric: 0.4941
# Epoch 8/10, train loss: 0.7138, train metric: 0.7510, valid metric: 0.5098
# Epoch 9/10, train loss: 0.7193, train metric: 0.7375, valid metric: 0.4510
# Epoch 10/10, train loss: 0.7186, train metric: 0.7527, valid metric: 0.5255
# tensor(0.4794, device='mps:0')
# Run #27
# Epoch 1/10, train loss: 0.6963, train metric: 0.7448, valid metric: 0.4863
# Epoch 2/10, train loss: 0.7123, train metric: 0.7448, valid metric: 0.4784
# Epoch 3/10, train loss: 0.6791, train metric: 0.7594, valid metric: 0.4784
# Epoch 4/10, train loss: 0.6682, train metric: 0.7650, valid metric: 0.4863
# Epoch 5/10, train loss: 0.6994, train metric: 0.7414, valid metric: 0.4706
# Epoch 6/10, train loss: 0.6710, train metric: 0.7600, valid metric: 0.4941
# Epoch 7/10, train loss: 0.6787, train metric: 0.7605, valid metric: 0.4510
# Epoch 8/10, train loss: 0.7072, train metric: 0.7504, valid metric: 0.4549
# Epoch 9/10, train loss: 0.6635, train metric: 0.7634, valid metric: 0.4667
# Epoch 10/10, train loss: 0.6792, train metric: 0.7605, valid metric: 0.5098
# tensor(0.4715, device='mps:0')
# Run #28
# Epoch 1/10, train loss: 0.6701, train metric: 0.7617, valid metric: 0.4745
# Epoch 2/10, train loss: 0.7189, train metric: 0.7386, valid metric: 0.5059
# Epoch 3/10, train loss: 0.6898, train metric: 0.7532, valid metric: 0.4745
# Epoch 4/10, train loss: 0.7152, train metric: 0.7544, valid metric: 0.4510
# Epoch 5/10, train loss: 0.7136, train metric: 0.7414, valid metric: 0.4863
# Epoch 6/10, train loss: 0.7152, train metric: 0.7527, valid metric: 0.4706
# Epoch 7/10, train loss: 0.6974, train metric: 0.7521, valid metric: 0.4824
# Epoch 8/10, train loss: 0.7104, train metric: 0.7431, valid metric: 0.5059
# Epoch 9/10, train loss: 0.7053, train metric: 0.7555, valid metric: 0.4588
# Epoch 10/10, train loss: 0.7006, train metric: 0.7521, valid metric: 0.4902
# tensor(0.4833, device='mps:0')
# Run #29
# Epoch 1/10, train loss: 0.7218, train metric: 0.7397, valid metric: 0.5216
# Epoch 2/10, train loss: 0.6711, train metric: 0.7577, valid metric: 0.5255
# Epoch 3/10, train loss: 0.7320, train metric: 0.7448, valid metric: 0.4549
# Epoch 4/10, train loss: 0.7112, train metric: 0.7437, valid metric: 0.4980
# Epoch 5/10, train loss: 0.6755, train metric: 0.7544, valid metric: 0.4824
# Epoch 6/10, train loss: 0.6989, train metric: 0.7544, valid metric: 0.5020
# Epoch 7/10, train loss: 0.7036, train metric: 0.7566, valid metric: 0.4588
# Epoch 8/10, train loss: 0.6794, train metric: 0.7645, valid metric: 0.4353
# Epoch 9/10, train loss: 0.7002, train metric: 0.7420, valid metric: 0.4902
# Epoch 10/10, train loss: 0.6719, train metric: 0.7628, valid metric: 0.5176
# tensor(0.4931, device='mps:0')
# Run #30
# Epoch 1/10, train loss: 0.6813, train metric: 0.7577, valid metric: 0.4784
# Epoch 2/10, train loss: 0.7174, train metric: 0.7341, valid metric: 0.5176
# Epoch 3/10, train loss: 0.7093, train metric: 0.7487, valid metric: 0.5020
# Epoch 4/10, train loss: 0.6913, train metric: 0.7397, valid metric: 0.4980
# Epoch 5/10, train loss: 0.6999, train metric: 0.7560, valid metric: 0.4980
# Epoch 6/10, train loss: 0.6933, train metric: 0.7532, valid metric: 0.4824
# Epoch 7/10, train loss: 0.6788, train metric: 0.7521, valid metric: 0.5490
# Epoch 8/10, train loss: 0.6920, train metric: 0.7634, valid metric: 0.4980
# Epoch 9/10, train loss: 0.6890, train metric: 0.7510, valid metric: 0.4902
# Epoch 10/10, train loss: 0.6354, train metric: 0.7645, valid metric: 0.5216
# tensor(0.4715, device='mps:0')

# %%
# history = train(model, optimizer, xentropy, accuracy,
#                 train_loader, valid_loader, n_epochs)
evaluate_tm(model, test_loader, accuracy)
# Out:
# tensor(0.4676, device='mps:0')

# %%
# history = train(model, optimizer, xentropy, accuracy,
#                 train_loader, valid_loader, n_epochs)
# evaluate_tm(model, test_loader, accuracy)

# %%
# for param in model.encoder.layers[-1].parameters():
#     param.requires_grad = True

# evaluate_tm(model, test_loader, accuracy)

# %%
# history = train(model, optimizer, xentropy, accuracy,
#                 train_loader, valid_loader, n_epochs)

# %%
# history = train(model, optimizer, xentropy, accuracy,
#                 train_loader, valid_loader, n_epochs)

# %%
# history = train(model, optimizer, xentropy, accuracy,
#                 train_loader, valid_loader, n_epochs)

# %%
# history = train(model, optimizer, xentropy, accuracy,
#                 train_loader, valid_loader, n_epochs)

# %%
# history = train(model, optimizer, xentropy, accuracy,
#                 train_loader, valid_loader, n_epochs)

# %%
# evaluate_tm(model, test_loader, accuracy)
