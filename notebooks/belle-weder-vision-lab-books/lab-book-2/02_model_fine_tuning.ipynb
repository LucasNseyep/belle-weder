# %%
def fetch_image_data():
    # TODO
    return

# %%
from pathlib import Path
import os

IMAGES_PATH = Path("../../../resources/cloud-images/CCSN_v2")

def index_labeled_images(images_path=IMAGES_PATH):
    cloud_labels = []
    images_path = Path(images_path)
    labeled_images = {}
    if not images_path.exists():
        return labeled_images

    for cloud_dir in sorted(p for p in images_path.iterdir() if p.is_dir()):
        for img_path in sorted(p for p in cloud_dir.iterdir() if p.is_file()):
            labeled_images[img_path.name] = {
                "label": cloud_dir.name,
                "path": str(img_path)
            }

    return labeled_images, cloud_labels

# %%
labeled_images, cloud_labels = index_labeled_images()

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

def extract_labels(labeled_images):
    images = []
    labels = []
    for (i, image_name) in enumerate(labeled_images):
        path = labeled_images[image_name]['path']
        image = cv2.imread(path)
        image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
        image = cv2.resize(image, (64, 64))
        images.append(image)

        label = labeled_images[image_name]['label']
        labels.append(label)

    return np.array(images), np.array(labels)

# %%
dataset_images, labels = extract_labels(labeled_images)

# %%
def split_train_test():
    # TODO with this and the below code blocks
    return

from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import LabelEncoder

ordinal_encoder = LabelEncoder()
labels_encoded = ordinal_encoder.fit_transform(labels)

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_idx, test_idx = next(sss.split(dataset_images, labels_encoded))

X_train, X_test = dataset_images[train_idx], dataset_images[test_idx]
y_train, y_test = labels_encoded[train_idx], labels_encoded[test_idx]

print("train:", X_train.shape, y_train.shape)
print("test: ", X_test.shape, y_test.shape)
# Out:
# train: (2034, 64, 64) (2034,)
# test:  (509, 64, 64) (509,)

# %%
X_train_flat = X_train.reshape(len(X_train), -1)
X_test_flat  = X_test.reshape(len(X_test), -1)

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

def display_clf_scores(labels, predictions):
    precision = precision_score(labels, predictions)
    recall = recall_score(labels, predictions)
    f1 = f1_score(labels, predictions)

    print("Precision:", precision)
    print("Recall:", recall)
    print("F1:", f1)

# %%
from typing import Dict, Any
import time
import numpy as np
import pandas as pd

from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier


def get_default_classifiers(random_state: int = 42) -> Dict[str, Any]:
    """
    Return a dictionary of main classification models (some with scaling).
    """
    return {
        "gaussian_nb": GaussianNB(),
        "log_reg": Pipeline([
            ("scaler", StandardScaler()),
            ("clf", LogisticRegression(max_iter=1000, random_state=random_state))
        ]),
        "linear_svc": Pipeline([
            ("scaler", StandardScaler()),
            ("clf", SGDClassifier(loss="hinge", random_state=random_state))
        ]),
        "svc_rbf": Pipeline([
            ("scaler", StandardScaler()),
            ("clf", SVC(kernel="rbf", probability=True, random_state=random_state))
        ]),
        "knn": Pipeline([
            ("scaler", StandardScaler()),
            ("clf", KNeighborsClassifier())
        ]),
        "decision_tree": DecisionTreeClassifier(random_state=random_state),
        "random_forest": RandomForestClassifier(random_state=random_state),
        "gradient_boosting": GradientBoostingClassifier(random_state=random_state,
                                                        n_estimators=150,
                                                        learning_rate=0.1,
                                                        max_depth=3,
                                                        subsample=0.7
                                                        ),
        "hist_gradient_boosting": HistGradientBoostingClassifier(random_state=random_state),
        "mlp": Pipeline([
            ("scaler", StandardScaler()),
            ("clf", MLPClassifier(max_iter=500, random_state=random_state))
        ])
    }


def evaluate_classifiers(X, y, scoring: str = "accuracy", cv: int = 5,
                         n_jobs: int = -1, random_state: int = 42,
                         verbose: int = 1
) -> pd.DataFrame:
    """
    Evaluate many classification models with default hyperparameters.
    Returns a sorted dataframe of cross-validation results.
    """
    classifiers = get_default_classifiers(random_state)
    cv_obj = StratifiedKFold(n_splits=cv, shuffle=True, random_state=random_state)

    results = []

    for name, clf in classifiers.items():
        if verbose:
            print(f"\nEvaluating model: {name}")

        t0 = time.perf_counter()

        scores = cross_val_score(
            clf, X, y,
            scoring=scoring,
            cv=cv_obj,
            n_jobs=n_jobs
        )

        t1 = time.perf_counter()

        results.append({
            "model": name,
            "mean_score": np.mean(scores),
            "std_score": np.std(scores),
            "time_elapsed": t1 - t0
        })

    return pd.DataFrame(results).sort_values("mean_score", ascending=False)

# %%
# can skip the below as we've concluded that we'll explore 1) random forest 2) mlp 3)svc

# results = evaluate_classifiers(X_train_flat, y_train, scoring="f1_macro", cv=5)
# print(results)
# Out:
# Evaluating model: gaussian_nb
#
# Evaluating model: log_reg
#
# Evaluating model: linear_svc
#
# Evaluating model: svc_rbf
#
# Evaluating model: knn
#
# Evaluating model: decision_tree
#
# Evaluating model: random_forest
#
# Evaluating model: gradient_boosting
#
# Evaluating model: hist_gradient_boosting
#
# Evaluating model: mlp
#                     model  mean_score  std_score  time_elapsed
# 7       gradient_boosting    0.249540   0.010886    917.842738
# 8  hist_gradient_boosting    0.248760   0.005808    123.033588
# 6           random_forest    0.242161   0.015370      3.676388
# 9                     mlp    0.211470   0.026213      4.508299
# 3                 svc_rbf    0.196986   0.013427     12.453825
# 2              linear_svc    0.190364   0.011519      5.036427
# 4                     knn    0.187575   0.012554      1.006303
# 5           decision_tree    0.178849   0.012698      4.152716
# 0             gaussian_nb    0.165809   0.005751      1.258407
# 1                 log_reg    0.165537   0.011160      5.153570

# %%
# Researching Random Forest Time estimate = ~ 400 seconds = ~ 7 minutes

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold

param_grid = {
    "n_estimators": [200, 350, 500],          # 3 levels: low / medium / higher
    "max_features": ["sqrt", "log2"],         # classic vs more random
    "max_depth": [10, 20, None],              # shallow/medium/deep
    "min_samples_leaf": [1, 2],               # low vs slightly regularized
    "bootstrap": [True, False],               # meaningful difference
    "class_weight": ["balanced"],             # fixed for small datasets
}

rf = RandomForestClassifier(random_state=42)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=cv,
    scoring="f1_macro",
    n_jobs=-1,
    verbose=3,
)


grid_search.fit(X_train_flat, y_train)

grid_search.best_params_, grid_search.best_score_
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 2/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.248 total time=   7.4s
# [CV 5/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.218 total time=   7.4s
# [CV 4/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.243 total time=   7.5s
# [CV 3/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.226 total time=   7.5s
# [CV 1/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.266 total time=   7.6s
# [CV 4/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=350;, score=0.259 total time=  13.0s
# [CV 1/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=350;, score=0.259 total time=  13.0s
# [CV 2/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=350;, score=0.258 total time=  13.1s
# [CV 3/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=350;, score=0.217 total time=  13.1s
# [CV 5/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=350;, score=0.229 total time=  13.2s
# [CV 2/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.241 total time=   7.3s
# [CV 1/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.235 total time=   7.3s
# [CV 4/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.238 total time=   7.2s
# [CV 3/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.236 total time=   7.4s
# [CV 2/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=500;, score=0.249 total time=  18.7s
# [CV 3/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=500;, score=0.201 total time=  18.7s
# [CV 1/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=500;, score=0.257 total time=  18.9s
# [CV 4/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=1, n_estimators=500;, score=0.256 total time=  18.9s
# [CV 5/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.212 total time=   7.4s
# [CV 1/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=log2, min_samples_leaf=1, n_estimators=200;, score=0.251 total time=   1.7s
# [CV 2/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=log2, min_samples_leaf=1, n_estimators=200;, score=0.251 total time=   1.7s
# [CV 3/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=log2, min_samples_leaf=1, n_estimators=200;, score=0.232 total time=   1.7s
# [CV 5/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=log2, min_samples_leaf=1, n_estimators=200;, score=0.231 total time=   1.7s
# [CV 4/5] END bootstrap=True, class_weight=balanced, max_depth=10, max_features=log2, min_samples_leaf=1, n_estimators=200;, score=0
1s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=20, max_features=sqrt, min_samples_leaf=2, n_estimators=500;, score=0.228 total time=  35.5s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.257 total time=  15.0s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.235 total time=  15.1s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.214 total time=  14.9s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.283 total time=  15.3s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.244 total time=  15.3s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=350;, score=0.245 total time=  26.5s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=350;, score=0.269 total time=  26.4s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.252 total time=  14.2s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.260 total time=  14.2s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=350;, score=0.224 total time=  26.3s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=350;, score=0.269 total time=  26.3s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.232 total time=  14.2s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.263 total time=  14.2s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=350;, score=0.228 total time=  26.6s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=200;, score=0.232 total time=  14.5s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=500;, score=0.248 total time=  37.9s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=500;, score=0.266 total time=  37.5s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=200;, score=0.242 total time=   3.2s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=500;, score=0.210 total time=  37.6s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=500;, score=0.270 total time=  37.5s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=200;, score=0.268 total time=   3.2s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=200;, score=0.223 total time=   3.2s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=200;, score=0.248 total time=   3.2s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=500;, score=0.224 total time=  37.9s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=350;, score=0.249 total time=  24.8s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=350;, score=0.276 total time=  24.5s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=200;, score=0.248 total time=   3.2s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=350;, score=0.239 total time=  24.5s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=350;, score=0.263 total time=  24.9s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=350;, score=0.227 total time=  25.0s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=350;, score=0.254 total time=   5.7s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=350;, score=0.254 total time=   5.6s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=350;, score=0.232 total time=   5.6s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=350;, score=0.254 total time=   5.7s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=350;, score=0.235 total time=   5.7s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=200;, score=0.243 total time=   3.0s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=200;, score=0.264 total time=   2.9s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=500;, score=0.247 total time=   8.1s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=200;, score=0.237 total time=   3.0s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=500;, score=0.258 total time=   8.0s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=200;, score=0.278 total time=   3.0s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=500;, score=0.236 total time=   8.1s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=500;, score=0.262 total time=   8.0s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=200;, score=0.244 total time=   3.0s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=500;, score=0.240 total time=   8.0s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=500;, score=0.279 total time=  35.1s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=500;, score=0.251 total time=  35.4s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=500;, score=0.238 total time=  35.0s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=350;, score=0.249 total time=   5.1s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=350;, score=0.224 total time=   5.2s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=350;, score=0.273 total time=   5.2s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=350;, score=0.272 total time=   5.1s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=350;, score=0.238 total time=   5.0s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=500;, score=0.252 total time=   6.5s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=500;, score=0.278 total time=   6.4s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=500;, score=0.223 total time=   6.3s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=500;, score=0.262 total time=   5.9s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=500;, score=0.251 total time=   5.9s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=500;, score=0.266 total time=  32.7s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=500;, score=0.239 total time=  32.6s
# ({'bootstrap': False,
#   'class_weight': 'balanced',
#   'max_depth': 20,
#   'max_features': 'log2',
#   'min_samples_leaf': 2,
#   'n_estimators': 350},
#  np.float64(0.25598076179872853))

# %%
import pandas as pd

results = grid_search.cv_results_
results_df = pd.DataFrame(grid_search.cv_results_)

param_cols = [c for c in results_df.columns if c.startswith("param_")]

visible_df = results_df[["rank_test_score", "mean_test_score"] + param_cols]
visible_df.sort_values("rank_test_score").head(20)
# Out:
#     rank_test_score  mean_test_score  param_bootstrap param_class_weight  \
# 58                1         0.255981            False           balanced
# 65                2         0.254518            False           balanced
# 57                3         0.254118            False           balanced
# 53                4         0.254107            False           balanced
# 33                5         0.254068             True           balanced
# 71                6         0.253296            False           balanced
# 69                7         0.253255            False           balanced
# 27                8         0.253026             True           balanced
# 59                9         0.252716            False           balanced
# 52               10         0.252194            False           balanced
# 35               11         0.251837             True           balanced
# 70               12         0.251099            False           balanced
# 64               13         0.250832            False           balanced
# 51               14         0.250149            False           balanced
# 29               15         0.249878             True           balanced
# 23               16         0.248838             True           balanced
# 68               17         0.248578            False           balanced
# 34               18         0.248011             True           balanced
# 63               19         0.247730            False           balanced
# 21               20         0.247690             True           balanced
#
#    param_max_depth param_max_features  param_min_samples_leaf  \
# 58              20               log2                       2
# 65            None               sqrt                       2
# 57              20               log2                       2
# 53              20               sqrt                       2
# 33            None               log2                       2
# 71            None               log2                       2
# 69            None               log2                       2
# 27            None               sqrt                       2
# 59              20               log2                       2
# 52              20               sqrt                       2
# 35            None               log2                       2
# 70            None               log2                       2
# 64            None               sqrt                       2
# 51              20               sqrt                       2
# 29            None               sqrt                       2
# 23              20               log2                       2
# 68            None               log2                       1
# 34            None               log2                       2
# 63            None               sqrt                       2
# 21              20               log2                       2
#
#     param_n_estimators
# 58                 350
# 65                 500
# 57                 200
# 53                 500
# 33                 200
# 71                 500
# 69                 200
# 27                 200
# 59                 500
# 52                 350
# 35                 500
# 70                 350
# 64                 350
# 51                 200
# 29                 500
# 23                 500
# 68                 500
# 34                 350
# 63                 200
# 21                 200

# %%
from scipy.stats import randint, uniform
import numpy as np
from sklearn.model_selection import RandomizedSearchCV

param_distributions = {
    "n_estimators": randint(200, 1000),
    "max_depth": randint(15, 25),
    "min_samples_leaf": randint(2, 5),
    "min_samples_split": randint(2, 30),
    "max_features": ["sqrt", "log2"],
    "bootstrap": [False],
    "class_weight": ["balanced"],
}

# %%
random_search = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_distributions,
    n_iter=100,
    scoring="f1_macro",
    cv=cv,
    n_jobs=-1,
    verbose=3,
    random_state=42,
)

random_search.fit(X_train_flat, y_train)

random_search.best_params_, random_search.best_score_
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=21, max_features=log2, min_samples_leaf=2, min_samples_split=16, n_estimators=306;, score=0.220 total time=   3.7s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=21, max_features=log2, min_samples_leaf=2, min_samples_split=16, n_estimators=306;, score=0.264 total time=   3.7s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=21, max_features=log2, min_samples_leaf=2, min_samples_split=16, n_estimators=306;, score=0.219 total time=   3.6s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=21, max_features=log2, min_samples_leaf=2, min_samples_split=16, n_estimators=306;, score=0.263 total time=   3.8s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=21, max_features=log2, min_samples_leaf=2, min_samples_split=16, n_estimators=306;, score=0.247 total time=   3.9s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=19, max_features=log2, min_samples_leaf=4, min_samples_split=23, n_estimators=508;, score=0.250 total time=   5.4s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=19, max_features=log2, min_samples_leaf=4, min_samples_split=23, n_estimators=508;, score=0.252 total time=   5.6s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=19, max_features=log2, min_samples_leaf=4, min_samples_split=23, n_estimators=508;, score=0.262 total time=   5.5s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=19, max_features=log2, min_samples_leaf=4, min_samples_split=23, n_estimators=508;, score=0.231 total time=   5.8s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=19, max_features=log2, min_samples_leaf=4, min_samples_split=23, n_estimators=508;, score=0.224 total time=   5.7s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=17, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=287;, score=0.262 total time=  16.7s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=17, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=287;, score=0.256 total time=  16.8s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=16, max_features=log2, min_samples_leaf=3, min_samples_split=7, n_estimators=585;, score=0.256 total time=   7.5s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=17, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=287;, score=0.237 total time=  16.8s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=16, max_features=log2, min_samples_leaf=3, min_samples_split=7, n_estimators=585;, score=0.257 total time=   7.4s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=17, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=287;, score=0.261 total time=  17.0s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=16, max_features=log2, min_samples_leaf=3, min_samples_split=7, n_estimators=585;, score=0.223 total time=   7.9s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=22, max_features=sqrt, min_samples_leaf=2, min_samples_split=8, n_estimators=321;, score=0.231 total time=  20.7s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=22, max_features=sqrt, min_samples_leaf=2, min_samples_split=8, n_estimators=321;, score=0.256 total time=  20.9s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=22, max_features=sqrt, min_samples_leaf=2, min_samples_split=8, n_estimators=321;, score=0.264 total time=  20.9s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=17, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=287;, score=0.229 total time=  17.4s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=22, max_features=sqrt, min_samples_leaf=2, min_samples_split=8, n_estimators=321;, score=0.265 total time=  21.2s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=22, max_features=sqrt, min_samples_leaf=2, min_samples_split=8, n_estimators=321;, score=0.240 total time=  21.4s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=16, max_features=log2, min_samples_leaf=3, min_samples_split=7, n_estimators=585;, score=0.273 total time=   7.8s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=16, max_features=log2, min_samples_leaf=3, min_samples_split=7, n_estimators=585;, score=0.250 total time=   7.9s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=24, max_features=log2, min_samples_leaf=4, min_samples_split=16, n_estimators=762;, score=0.245 total time=   9.5s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=24, max_features=log2, min_samples_leaf=4, min_samples_split=16, n_estimators=762;, score=0.257 total time=   9.3s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=24, max_features=log2, min_samples_leaf=4, min_samples_split=16, n_estimators=762;, score=0.207 total time=   9.2s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=24, max_features=log2, min_samples_leaf=4, min_samples_split=16, n_estimators=762;, score=0.282 total time=   9.2s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=24, max_features=log2, min_samples_leaf=4, min_samples_split=16, n_estimators=762;, score=0.228 total time=   9.1s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=21, max_features=log2, min_samples_leaf=2, min_samples_split=4, n_estimators=684;, score=0.251 total time=  10.2s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=21, max_features=log2, min_samples_leaf=2, min_samples_split=4, n_estimators=684;, score=0.276 total time=   9.8s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=19, max_features=sqrt, min_samples_leaf=3, min_samples_split=23, n_estimators=452;, score=0.258 total time=  25.6s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=19, max_features=sqrt, min_samples_leaf=3, min_samples_split=23, n_estimators=452;, score=0.254 total time=  25.9s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=19, max_features=sqrt, min_samples_leaf=3, min_samples_split=23, n_estimators=452;, score=0.266 total time=  26.1s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=19, max_features=sqrt, min_samples_leaf=3, min_samples_split=23, n_estimators=452;, score=0.221 total time=  26.2s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=19, max_features=sqrt, min_samples_leaf=3, min_samples_split=23, n_estimators=452;, score=0.230 total time=  26.7s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=21, max_features=log2, min_samples_leaf=2, min_samples_split=4, n_estimators=684;, score=0.225 total time=  10.1s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=16, max_features=log2, min_samples_leaf=2, min_samples_split=29, n_estimators=213;, score=0.251 total time=   2.5s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=16, max_features=log2, min_samples_leaf=2, min_samples_split=29, n_estimators=213;, score=0.253 total time=   2.4s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=16, max_features=log2, min_samples_leaf=2, min_samples_split=29, n_estimators=213;, score=0.233 total time=   2.4s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=16, max_features=log2, min_samples_leaf=2, min_samples_split=29, n_estimators=213;, score=0.246 total time=   2.5s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=21, max_features=log2, min_samples_leaf=2, min_samples_split=4, n_estimators=684;, score=0.264 total time=  10.3s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=16, max_features=log2, min_samples_leaf=2, min_samples_split=29, n_estimators=213;, score=0.221 total time=   2.4s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=21, max_features=log2, min_samples_leaf=2, min_samples_split=4, n_estimators=684;, score=0.244 total time=  10.5s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=23, max_features=sqrt, min_samples_leaf=4, min_samples_split=28, n_estimators=710;, score=0.248 total time=  39.2s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=16, max_features=log2, min_samples_leaf=2, min_samples_split=27, n_estimators=764;, score=0.249 total time=   8.7s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=16, max_features=log2, min_samples_leaf=2, min_samples_split
4s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=19, max_features=sqrt, min_samples_leaf=2, min_samples_split=29, n_estimators=819;, score=0.217 total time=  47.2s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=17, max_features=log2, min_samples_leaf=3, min_samples_split=24, n_estimators=545;, score=0.243 total time=   6.5s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=17, max_features=log2, min_samples_leaf=3, min_samples_split=24, n_estimators=545;, score=0.260 total time=   6.3s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=19, max_features=log2, min_samples_leaf=2, min_samples_split=24, n_estimators=326;, score=0.252 total time=   3.9s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=19, max_features=log2, min_samples_leaf=2, min_samples_split=24, n_estimators=326;, score=0.245 total time=   4.0s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=17, max_features=log2, min_samples_leaf=3, min_samples_split=24, n_estimators=545;, score=0.221 total time=   6.4s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=17, max_features=log2, min_samples_leaf=3, min_samples_split=24, n_estimators=545;, score=0.270 total time=   6.4s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=19, max_features=log2, min_samples_leaf=2, min_samples_split=24, n_estimators=326;, score=0.226 total time=   3.9s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=17, max_features=log2, min_samples_leaf=3, min_samples_split=24, n_estimators=545;, score=0.228 total time=   6.3s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=19, max_features=log2, min_samples_leaf=2, min_samples_split=24, n_estimators=326;, score=0.240 total time=   3.9s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=19, max_features=log2, min_samples_leaf=2, min_samples_split=24, n_estimators=326;, score=0.223 total time=   3.8s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=23, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=257;, score=0.236 total time=   3.6s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=23, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=257;, score=0.270 total time=   3.6s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=23, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=257;, score=0.272 total time=   3.4s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=23, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=257;, score=0.227 total time=   3.5s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=23, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=257;, score=0.238 total time=   3.4s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=19, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=549;, score=0.218 total time=  31.3s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=19, n_estimators=835;, score=0.250 total time=  43.0s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=19, n_estimators=835;, score=0.253 total time=  43.9s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=19, n_estimators=835;, score=0.227 total time=  43.2s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=19, n_estimators=835;, score=0.261 total time=  43.4s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=19, n_estimators=835;, score=0.219 total time=  43.4s
# ({'bootstrap': False,
#   'class_weight': 'balanced',
#   'max_depth': 21,
#   'max_features': 'sqrt',
#   'min_samples_leaf': 3,
#   'min_samples_split': 2,
#   'n_estimators': 247},
#  np.float64(0.2551676615920409))

# %%
import pandas as pd

results = random_search.cv_results_
results_df = pd.DataFrame(random_search.cv_results_)

param_cols = [c for c in results_df.columns if c.startswith("param_")]

visible_df = results_df[["rank_test_score", "mean_test_score"] + param_cols]
visible_df.sort_values("rank_test_score").head(20)
# Out:
#     rank_test_score  mean_test_score  param_bootstrap param_class_weight  \
# 25                1         0.255168            False           balanced
# 59                2         0.254793            False           balanced
# 92                3         0.253601            False           balanced
# 64                4         0.253137            False           balanced
# 8                 5         0.252068            False           balanced
# 4                 6         0.251873            False           balanced
# 28                7         0.251663            False           balanced
# 1                 8         0.251116            False           balanced
# 37                9         0.251106            False           balanced
# 40               10         0.250882            False           balanced
# 48               11         0.250580            False           balanced
# 2                12         0.249191            False           balanced
# 80               13         0.249162            False           balanced
# 83               14         0.249108            False           balanced
# 99               15         0.248576            False           balanced
# 55               16         0.248349            False           balanced
# 56               17         0.248160            False           balanced
# 47               18         0.248017            False           balanced
# 86               19         0.247860            False           balanced
# 14               20         0.247850            False           balanced
#
#     param_max_depth param_max_features  param_min_samples_leaf  \
# 25               21               sqrt                       3
# 59               15               log2                       2
# 92               20               sqrt                       3
# 64               20               log2                       3
# 8                21               log2                       2
# 4                16               log2                       3
# 28               19               sqrt                       3
# 1                22               sqrt                       2
# 37               24               sqrt                       2
# 40               20               log2                       4
# 48               16               sqrt                       3
# 2                17               sqrt                       4
# 80               20               log2                       4
# 83               24               sqrt                       2
# 99               23               log2                       2
# 55               21               log2                       2
# 56               21               log2                       2
# 47               21               sqrt                       2
# 86               24               sqrt                       2
# 14               18               log2                       3
#
#     param_min_samples_split  param_n_estimators
# 25                        2                 247
# 59                       17                 453
# 92                       12                 643
# 64                        4                 311
# 8                         4                 684
# 4                         7                 585
# 28                        4                 968
# 1                         8                 321
# 37                        8                 389
# 40                       10                 517
# 48                        7                 615
# 2                        12                 287
# 80                        9                 885
# 83                       10                 445
# 99                        2                 257
# 55                        2                 839
# 56                       12                 672
# 47                        2                 602
# 86                        5                 884
# 14                        7                 765

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_predict


rf_clf = random_search.best_estimator_ #this is the model, fully trained on the training set

# %%
cross_val_score(rf_clf, X_train_flat, y_train, cv=3, scoring="f1_macro")
# Out:
# array([0.22890253, 0.22539575, 0.26556487])

# %%
y_train_pred = cross_val_predict(rf_clf, X_train_flat, y_train, cv=3)

# %%
y_train_labels = ordinal_encoder.inverse_transform(y_train)
y_train_pred_labels = ordinal_encoder.inverse_transform(y_train_pred)

fig, axes = plt.subplots(1, 2, figsize=(15, 6))

conf_mx = ConfusionMatrixDisplay.from_predictions(y_train_labels, y_train_pred_labels, ax=axes[0])
axes[0].set_title('Raw Confusion Matrix (Counts)')

conf_mx_norm = ConfusionMatrixDisplay.from_predictions(y_train_labels, y_train_pred_labels, normalize="true", values_format=".0%", labels=ordinal_encoder.classes_, ax=axes[1])
axes[1].set_title('Normalized Confusion Matrix (Row Percentage)')

plt.tight_layout()
plt.show()

# %%
# zeroing the diagonal in the Confusion Matrix

sample_weight = (y_train_pred_labels != y_train_labels)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))


zeroed_conf_mx = ConfusionMatrixDisplay.from_predictions(y_train_labels, y_train_pred_labels, sample_weight=sample_weight, labels=

                                                         , ax=axes[0])
zeroed_conf_mx_norm = ConfusionMatrixDisplay.from_predictions(y_train_labels, y_train_pred_labels, normalize="true", values_format=".0%", labels=
                                                              , sample_weight=sample_weight, ax=axes[1])

axes[0].set_title('Raw Confusion Matrix (Counts)')
axes[1].set_title('Normalized Confusion Matrix (Row Percentage)')

plt.tight_layout()
plt.show()

# %%
zeroed_conf_mx_row = ConfusionMatrixDisplay.from_predictions(y_train_labels, y_train_pred_labels,
                                                             sample_weight=sample_weight,
                                                             normalize="true", values_format=".0%")
zeroed_conf_mx_norm_col = ConfusionMatrixDisplay.from_predictions(y_train_labels, y_train_pred_labels,
                                                                  normalize="pred", values_format=".0%",
                                                                  labels=ordinal_encoder.classes_,
                                                                  sample_weight=sample_weight)
plt.show()

# %%
def plot_image(image_data):
    image = image_data.reshape(28, 28)
    plt.imshow(image)
    plt.axis("off")

# %%
cl_a, cl_b = 'Ac', 'Cc'
idx_a = ordinal_encoder.transform([cl_a])[0]
idx_b = ordinal_encoder.transform([cl_b])[0]
X_aa = X_train[(y_train == idx_a) & (y_train_pred == idx_a)]
X_ab = X_train[(y_train == idx_a) & (y_train_pred == idx_b)]
X_ba = X_train[(y_train == idx_b) & (y_train_pred == idx_a)]
X_bb = X_train[(y_train == idx_b) & (y_train_pred == idx_b)]

plt.imshow(X_aa[0])
plt.show()

# %%
size = 5
pad = 0.2
plt.figure(figsize=(size, size))
for images, (label_col, label_row) in [(X_ba, (0, 0)), (X_bb, (1, 0)),
                                       (X_aa, (0, 1)), (X_ab, (1, 1))]:
    for idx, image_data in enumerate(images[:size*size]):
        x = idx % size + label_col * (size + pad)
        y = idx // size + label_row * (size + pad)
        plt.imshow(image_data.reshape(64, 64),
                   extent=(x, x + 1, y, y + 1))
plt.xticks([size / 2, size + pad + size / 2], [str(cl_a), str(cl_b)])
plt.yticks([size / 2, size + pad + size / 2], [str(cl_b), str(cl_a)])
plt.plot([size + pad / 2, size + pad / 2], [0, 2 * size + pad], "k:")
plt.plot([0, 2 * size + pad], [size + pad / 2, size + pad / 2], "k:")
plt.axis([0, 2 * size + pad, 0, 2 * size + pad])
plt.xlabel("Predicted label")
plt.ylabel("True label")
# save_fig("error_analysis_digits_plot")
plt.show()

# %%
y_test_pred = cross_val_predict(rf_clf, X_test_flat, y_test, cv=3)

# %%
final_model = random_search.best_estimator_

# %%
final_predictions = rf_clf.predict(X_test_flat)

# %%
from sklearn.metrics import classification_report

print("\n--------------- Classification Report ---------------")
print(classification_report(y_test, final_predictions))
# Out:
# --------------- Classification Report ---------------
#               precision    recall  f1-score   support
#
#            0       0.28      0.18      0.22        44
#            1       0.36      0.13      0.19        38
#            2       0.32      0.52      0.39        48
#            3       0.24      0.33      0.28        54
#            4       0.19      0.14      0.16        28
#            5       0.27      0.21      0.24        58
#            6       0.41      0.70      0.51        40
#            7       0.25      0.19      0.22        36
#            8       0.21      0.20      0.20        55
#            9       0.42      0.46      0.44        68
#           10       0.17      0.10      0.12        40
#
#     accuracy                           0.30       509
#    macro avg       0.28      0.29      0.27       509
# weighted avg       0.29      0.30      0.28       509

# %%
# Production ready model

full_dataset = dataset_images.reshape(len(dataset_images), -1)

production_clf = RandomForestClassifier(bootstrap=False,
  class_weight='balanced',
  max_depth=21,
  max_features='sqrt',
  min_samples_leaf= 3,
  min_samples_split= 2,
  n_estimators=247).fit(full_dataset, labels_encoded) #to save using joblib or other
# Out:
# 2543

# %%
# Unecessary

# Defo overfitting here

production_predictions = production_clf.predict(full_dataset)

dataset_labels = ordinal_encoder.inverse_transform(labels_encoded)
production_labels = ordinal_encoder.inverse_transform(production_predictions)

conf_mx = ConfusionMatrixDisplay.from_predictions(dataset_labels, production_labels)
conf_mx_norm = ConfusionMatrixDisplay.from_predictions(dataset_labels, production_labels, normalize="true", values_format=".0%", labels=ordinal_encoder.classes_)
plt.show()

# %%
scores = cross_val_score(
            production_clf, full_dataset, dataset_labels,
            scoring="f1_macro",
            cv=5,
            n_jobs=-1
        )

# %%
display_scores(scores)
# Out:
# Scores: [0.21016552 0.22257577 0.21646765 0.21768024 0.21666611]
# Mean: 0.21671105752269418
# Standard deviation: 0.003955744707833014

# %%
# mlp

# %%
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import MinMaxScaler



# pipeline = make_pipeline(MinMaxScaler(), mlp_clf)
mlp_clf = MLPClassifier(max_iter=1000, random_state=42)


pipeline = Pipeline([("scaler", StandardScaler()), ("clf", mlp_clf)])

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

scores = cross_val_score(
            pipeline, X_train_flat, y_train,
            scoring="f1_macro",
            cv=cv,
            n_jobs=-1
        )
# Out:
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/lucasnseyep/code/LucasNseyep/belle-weder/.venv/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b

# %%
display_scores(scores)
# Out:
# Scores: [0.20804118 0.18606165 0.23401166 0.2481606  0.18107341]
# Mean: 0.21146970173038207
# Standard deviation: 0.02621305238144969

# %%
scores.best_validation_score_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 scores.best_validation_score_
#
# AttributeError: 'numpy.ndarray' object has no attribute 'best_validation_score_'
